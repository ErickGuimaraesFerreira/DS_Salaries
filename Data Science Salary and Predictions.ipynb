# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("sample_data/ds_salaries.csv")

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df['experience_level'] = df['experience_level'].replace('SE', 'Senior_Level')
df['experience_level'] = df['experience_level'].replace('MI', 'Mid_Level')
df['experience_level'] = df['experience_level'].replace('EN', 'Entry_Level')
df['experience_level'] = df['experience_level'].replace('EX', 'Executive_Level')
df['employment_type'] = df['employment_type'].replace('FT', 'Full_Time')
df['employment_type'] = df['employment_type'].replace('CT', 'Contractual')
df['employment_type'] = df['employment_type'].replace('FL', 'Freelancer')
df['employment_type'] = df['employment_type'].replace('PT', 'Part_Time')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior_Level       Full_Time  Principal Data Scientist
# 1          2023        Mid_Level     Contractual               ML Engineer
# 2          2023        Mid_Level     Contractual               ML Engineer
# 3          2023     Senior_Level       Full_Time            Data Scientist
# 4          2023     Senior_Level       Full_Time            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior_Level       Full_Time            Data Scientist
# 3751       2021        Mid_Level       Full_Time  Principal Data Scientist
# 3752       2020      Entry_Level       Full_Time            Data Scientist
# 3753       2020      Entry_Level     Contractual     Business Data Analyst
# 3754       2021     Senior_Level       Full_Time      Data Science Manager
#
# ...

# %%
print(df.dtypes)
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df['remote_ratio'].value_counts()
# Out:
# 0      1923
# 100    1643
# 50      189
# Name: remote_ratio, dtype: int64

# %%
df.drop(['salary'], axis=1, inplace=True)

# %%
pd.set_option('display.precision', 2)

# %%
import matplotlib.pyplot as plt
#Armazenando a contagem de valores da coluna work_year na variável work_counts
work_counts = df['work_year'].value_counts()
#Ajustando o tamanho do gráfico
fig = plt.figure(figsize=(16, 12))
#Plotando o gráfico com resultado da contagem em porcentagem
work_counts.plot(autopct='%.0f%%', kind='pie')
plt.show()

# %%
df['experience_level'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
functions = df[df['work_year']==2023]['job_title'].value_counts().reset_index()[:10]

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df,palette='mako',)
# Out:
# <Axes: xlabel='experience_level', ylabel='salary_in_usd'>

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.stripplot(x='experience_level', y='salary_in_usd', data=df, palette='mako')
# Out:
# <ipython-input-18-ffa608c2d2c6>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='experience_level', y='salary_in_usd', data=df, palette='mako')
# <Axes: xlabel='experience_level', ylabel='salary_in_usd'>

# %%
df['employment_type'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(13,8))
df['job_title'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
# Contar o número de vagas para cada cargo
contagem_vagas = df['job_title'].value_counts()

# Selecionar os 10 cargos com o maior número de vagas
top_10_cargos = contagem_vagas.head(10).index.tolist()

# Filtrar o DataFrame apenas para os 10 cargos selecionados
df_top_10 = df[df['job_title'].isin(top_10_cargos)]

# Calcular a média salarial para cada cargo
media_salario = df_top_10.groupby('job_title')['salary_in_usd'].mean()

plt.figure(figsize=(10, 8))  # Ajuste os valores de largura e altura conforme necessário

# Criar o gráfico de barras
plt.bar(media_salario.index, media_salario.values)
plt.xticks(rotation=45)
plt.xlabel('Cargo')
plt.ylabel('Média Salarial')
plt.title('Média Salarial dos 10 Cargos com Maior Número de Vagas')
plt.xticks(rotation=75)  # Ajuste o ângulo de rotação conforme necessário


# Exibir o gráfico
plt.show()

# %%
sl = df.groupby(['work_year'])['salary_in_usd'].mean()

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x = sl.index, y = sl.values)
# Out:
# <Axes: xlabel='work_year'>

# %%
df.hist(bins=20, figsize=(15,7))
# Out:
# array([[<Axes: title={'center': 'work_year'}>,
#         <Axes: title={'center': 'salary_in_usd'}>],
#        [<Axes: title={'center': 'remote_ratio'}>, <Axes: >]], dtype=object)

# %%
df.corr()['salary_in_usd'].sort_values(ascending=False)
# Out:
# <ipython-input-24-e8f943b6c6e4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['salary_in_usd'].sort_values(ascending=False)
# salary_in_usd    1.00
# work_year        0.23
# remote_ratio    -0.06
# Name: salary_in_usd, dtype: float64

# %%
## Crie um gráfico de dispersão do salário em USD vs. o nível de experiência
plt.scatter(df['experience_level'], df['salary_in_usd'])

# Defina o título e as etiquetas do gráfico
plt.title('Relação entre o salário e o nível de experiência')
plt.xlabel('Nível de experiência')
plt.ylabel('Salário em USD')

# Mostre o gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="employment_type", y="salary_in_usd", hue="experience_level", data=df)
plt.xlabel("Tipo de Contrato")
plt.ylabel("Salario")
plt.title("Média Salarial por Tipo de Contrato e Nível de Experiência")
plt.show()

# %%
df.drop(["salary"], axis=1, inplace=True)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlação")
plt.show()
# Out:
# <ipython-input-57-4c4c4024a997>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="coolwarm")

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Transformar os dados usando o LabelEncoder
cols = ['experience_level', 'employment_type', 'job_title','salary_currency','employee_residence','company_location','company_size']
df[cols]=df[cols].apply(LabelEncoder().fit_transform)

# Criar X, y
X = df.drop(["salary_in_usd"], axis=1)
y = df["salary_in_usd"]

# Construir conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import tensorflow as tf

# %%
tf.random.set_seed(42)

# Criar um modelo
modelo = tf.keras.Sequential([
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(1),
])

# Compilar o modelo
modelo.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["mae"])

# Adaptar o modelo
história = modelo.fit(X_train, y_train, epochs=150)
# Out:
# Epoch 1/150
# 83/83 [==============================] - 1s 2ms/step - loss: 133129.8438 - mae: 133129.8438
# Epoch 2/150
# 83/83 [==============================] - 0s 2ms/step - loss: 122959.0000 - mae: 122959.0000
# Epoch 3/150
# 83/83 [==============================] - 0s 2ms/step - loss: 96411.1562 - mae: 96411.1562
# Epoch 4/150
# 83/83 [==============================] - 0s 2ms/step - loss: 62099.3867 - mae: 62099.3867
# Epoch 5/150
# 83/83 [==============================] - 0s 2ms/step - loss: 61291.2617 - mae: 61291.2617
# Epoch 6/150
# 83/83 [==============================] - 0s 2ms/step - loss: 61245.6016 - mae: 61245.6016
# Epoch 7/150
# 83/83 [==============================] - 0s 2ms/step - loss: 61254.4844 - mae: 61254.4844
# Epoch 8/150
# 83/83 [==============================] - 0s 2ms/step - loss: 61258.2148 - mae: 61258.2148
# Epoch 9/150
# 83/83 [==============================] - 0s 2ms/step - loss: 61116.2617 - mae: 61116.2617
# Epoch 10/150
# ...

# %%
prediction = modelo.predict(X_test)
# Out:
# 36/36 [==============================] - 0s 2ms/step

# %%
prediction = np.ravel(prediction)

# %%
y_pred = modelo.predict(X_test)

plt.figure(figsize=(14, 6))
plt.plot(y_test, label='Valores Reais', marker='o')
plt.plot(y_pred, label='Previsão', marker='x')
plt.title('Valores Reais vs Previsão')
plt.xlabel('Sample')
plt.ylabel('Valor')
plt.legend()
plt.show()
# Out:
# 36/36 [==============================] - 0s 1ms/step

# %%
df_final = pd.DataFrame({"Y_test": y_test , "Prediction" : prediction})

# Sort index before plot
df_final = df_final.sort_index()

# Plot the final result
plt.figure(figsize= (18,5))
plt.plot(df_final)
plt.legend(["Atual" , "Previsão"])
